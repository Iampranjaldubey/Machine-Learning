# %%
import pandas as pd
import numpy as np

data = pd.read_csv("cgpa_package.csv")

x = data["CGPA"].values.reshape(-1, 1)
y = data["Package_LPA"].values.reshape(-1, 1)

X = np.hstack((x, np.ones((x.shape[0], 1))))
w = np.linalg.inv(X.T @ X) @ X.T @ y

m = w[0,0]
c = w[1,0]

print("m =", m)
print("c =", c)
8
y_pred = X @ w
# Out:
# m = 1.4745212903689648
# c = -3.732096240782063

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y, label="Actual data")
plt.plot(x,y_pred, color='red', label="regression line")
plt.xlabel("CGPA")
plt.ylabel("Package(LPA)")
plt.legend()
plt.show()

# %%
mse=np.mean((y-y_pred)**2)
print(mse)
# Out:
# 0.6236601705322182
