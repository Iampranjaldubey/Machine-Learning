# %% [markdown]
# # logistic regression with multinomial

# %% [markdown]
# level encoder
# stratify(used for balancing training data(multi classes) in training)

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
movies = pd.read_csv("tmdb_5000_movies.csv")

# %%
movies.shape
# Out:
# (4803, 20)

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   str
#  2   homepage              1712 non-null   str
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   str
#  5   original_language     4803 non-null   str
#  6   original_title        4803 non-null   str
#  7   overview              4800 non-null   str
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   str
#  10  production_countries  4803 non-null   str
#  11  release_date          4802 non-null   str
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   str
# ...

# %%
credit = pd.read_csv("tmdb_5000_credits.csv", encoding='utf-8', encoding_errors='ignore', engine='python')

# %%
credit.shape
# Out:
# (4803, 4)

# %%
credit.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   str
#  2   cast      4803 non-null   str
#  3   crew      4803 non-null   str
# dtypes: int64(1), str(3)
# memory usage: 150.2 KB

# %%
movies = movies.merge(credit, on='title')

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4789 entries, 0 to 4788
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4789 non-null   int64
#  1   genres                4789 non-null   str
#  2   homepage              1709 non-null   str
#  3   id                    4789 non-null   int64
#  4   keywords              4789 non-null   str
#  5   original_language     4789 non-null   str
#  6   original_title        4789 non-null   str
#  7   overview              4786 non-null   str
#  8   popularity            4789 non-null   float64
#  9   production_companies  4789 non-null   str
#  10  production_countries  4789 non-null   str
#  11  release_date          4788 non-null   str
#  12  revenue               4789 non-null   int64
#  13  runtime               4787 non-null   float64
#  14  spoken_languages      4789 non-null   str
# ...

# %%
movies.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3080
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  840
# title                      0
# vote_average               0
# vote_count                 0
# movie_id                   0
# cast                       0
# crew                       0
# dtype: int64

# %%
movies = movies[["movie_id", "title", "overview", "genres", "keywords", "cast", "crew"]]
